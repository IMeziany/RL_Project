# %% [markdown]
# # Task 1: DQN Agent Implementation
#
# A DQN agent was implemented, trained, and evaluated. The impact of key hyperparameters was explored through a simple grid search.
#
# **Author:** Yuxian Zuo

# %% [markdown]
# ## Setup

# %%
import gymnasium as gym
import highway_env
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import random
import itertools
from collections import deque
from IPython.display import clear_output
import time
from copy import deepcopy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## Training Process

# %%
# Load config
with open("configs/config.pkl", "rb") as f:
    config = pickle.load(f)

env = gym.make("highway-fast-v0", render_mode=None, config=config)
state_dim = env.observation_space.shape[0]
n_actions = env.action_space.n

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, state, action, reward, done, next_state):
        self.buffer.append((state, action, reward, done, next_state))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        state, action, reward, done, next_state = map(np.array, zip(*batch))
        return state, action, reward, done, next_state

    def __len__(self):
        return len(self.buffer)

# %%
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions),
        )

    def forward(self, x):
        return self.net(x)

# %%
class DQN_Skeleton:
    def __init__(self,
                 action_space,
                 observation_space,
                 gamma,
                 batch_size,
                 buffer_capacity,
                 update_target_every,
                 epsilon_start,
                 decrease_epsilon_factor,
                 epsilon_min,
                 learning_rate,
                 hidden_size,
                ):
        self.action_space = action_space
        self.observation_space = observation_space
        self.gamma = gamma

        self.batch_size = batch_size
        self.buffer_capacity = buffer_capacity
        self.update_target_every = update_target_every

        self.epsilon_start = epsilon_start
        self.decrease_epsilon_factor = decrease_epsilon_factor
        self.epsilon_min = epsilon_min

        self.learning_rate = learning_rate
        self.hidden_size = hidden_size

        self.reset()

    def get_q(self, state):
        state_tensor = torch.tensor(state, dtype=torch.float32).flatten().unsqueeze(0).to(device)
        with torch.no_grad():
            output = self.q_net.forward(state_tensor)
        return output.cpu().numpy()[0]

    def get_action(self, state, epsilon=None):
        if epsilon is None:
            epsilon = self.epsilon

        if np.random.rand() < epsilon:
            return self.action_space.sample()
        else:
            return np.argmax(self.get_q(state))
        
    def update(self, state, action, reward, done, next_state):
        self.buffer.push(state, action, reward, done, next_state)

        if len(self.buffer) < self.batch_size:
            return None

        states, actions, rewards_, dones, next_states = self.buffer.sample(self.batch_size)

        states = torch.FloatTensor(states).view(states.shape[0], -1).to(device)
        actions = torch.LongTensor(actions).unsqueeze(1).to(device)
        rewards_ = torch.FloatTensor(rewards_).unsqueeze(1).to(device)
        dones = torch.FloatTensor(dones).unsqueeze(1).to(device)
        next_states = torch.FloatTensor(next_states).view(next_states.shape[0], -1).to(device)

        q_values = self.q_net(states).gather(1, actions)
        next_q_values = self.target_net(next_states).max(1)[0].unsqueeze(1)
        targets = rewards_ + self.gamma * next_q_values * (1 - dones)

        loss = self.loss_function(q_values, targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        if self.n_steps % self.update_target_every == 0:
            self.target_net.load_state_dict(self.q_net.state_dict())

        self.n_steps += 1
        if done:
            self.n_eps += 1
            self.decrease_epsilon()

        return loss.item()
    
    def decrease_epsilon(self):
        self.epsilon = self.epsilon_min + (self.epsilon_start - self.epsilon_min) * (
            np.exp(-1.0 * self.n_eps / self.decrease_epsilon_factor)
        )

    def reset(self):
        hidden_size = self.hidden_size
        obs_size = int(np.prod(self.observation_space.shape))
        n_actions = self.action_space.n

        self.buffer = ReplayBuffer(self.buffer_capacity)
        self.q_net = Net(obs_size, hidden_size, n_actions).to(device)
        self.target_net = Net(obs_size, hidden_size, n_actions).to(device)


        self.loss_function = nn.MSELoss()
        self.optimizer = optim.Adam(self.q_net.parameters(), lr=self.learning_rate)

        self.epsilon = self.epsilon_start
        self.n_steps = 0
        self.n_eps = 0

# %%
def eval_agent(agent, env, n_sim=5):
    env_copy = deepcopy(env)
    episode_rewards = np.zeros(n_sim)

    for i in range(n_sim):
        state, _ = env_copy.reset()
        done = False
        reward_sum = 0

        while not done:
            action = agent.get_action(state, epsilon=0)  # no exploration
            state, reward, terminated, truncated, _ = env_copy.step(action)
            reward_sum += reward
            done = terminated or truncated

        episode_rewards[i] = reward_sum

    return episode_rewards

# %%
def train(env, agent, N_episodes, eval_every=10, reward_threshold=300):
    total_time = 0
    losses = []
    reward_history = []

    for ep in range(N_episodes):
        state, _ = env.reset()
        done = False

        while not done:
            action = agent.get_action(state)
            next_state, reward, terminated, truncated, _ = env.step(action)
            loss_val = agent.update(state, action, reward, terminated, next_state)

            state = next_state
            done = terminated or truncated
            total_time += 1

            if loss_val is not None:
                losses.append(loss_val)

        if (ep + 1) % eval_every == 0:
            rewards = eval_agent(agent, env)
            avg_reward = np.mean(rewards)
            reward_history.append(avg_reward)
            print(f"episode {ep+1}, reward = {avg_reward:.2f}, epsilon = {agent.epsilon:.3f}")

            if avg_reward >= reward_threshold:
                print("Stopping early — reward threshold reached.")
                break

    return losses, reward_history

# %%
hidden_size = 128
buffer_capacity = 20000
batch_size = 64
gamma = 0.99
epsilon_start = 0.9
epsilon_min = 0.05
decrease_epsilon_factor = 1000
update_target_every = 200
learning_rate = 1e-4

# %%
agent = DQN_Skeleton(
    action_space=env.action_space,
    observation_space=env.observation_space,
    gamma=gamma,
    batch_size=batch_size,
    buffer_capacity=buffer_capacity,
    update_target_every=update_target_every,
    epsilon_start=epsilon_start,
    decrease_epsilon_factor=decrease_epsilon_factor,
    epsilon_min=epsilon_min,
    learning_rate=learning_rate,
    hidden_size=hidden_size
)

N_episodes = 300
losses, rewards = train(env, agent, N_episodes=300)
# Out:
# episode 10, reward = 12.76, epsilon = 0.895
# episode 20, reward = 38.66, epsilon = 0.887
# episode 30, reward = 48.32, epsilon = 0.879
# episode 40, reward = 45.01, epsilon = 0.871
# episode 50, reward = 41.67, epsilon = 0.863
# episode 60, reward = 38.59, epsilon = 0.855
# episode 70, reward = 26.11, epsilon = 0.847
# episode 80, reward = 43.77, epsilon = 0.839
# episode 90, reward = 47.50, epsilon = 0.832
# episode 100, reward = 34.91, epsilon = 0.825
# episode 110, reward = 51.99, epsilon = 0.818
# episode 120, reward = 47.85, epsilon = 0.811
# episode 130, reward = 44.85, epsilon = 0.805
# episode 140, reward = 45.43, epsilon = 0.799
# episode 150, reward = 51.25, epsilon = 0.792
# episode 160, reward = 48.24, epsilon = 0.785
# episode 170, reward = 37.75, epsilon = 0.777
# episode 180, reward = 44.89, epsilon = 0.771
# episode 190, reward = 43.52, epsilon = 0.764
# episode 200, reward = 48.77, epsilon = 0.757
# episode 210, reward = 36.44, epsilon = 0.751
# episode 220, reward = 48.75, epsilon = 0.745
# episode 230, reward = 49.20, epsilon = 0.738
# episode 240, reward = 47.32, epsilon = 0.731
# episode 250, reward = 47.50, epsilon = 0.726
# episode 260, reward = 44.24, epsilon = 0.721
# episode 270, reward = 43.30, epsilon = 0.715
# episode 280, reward = 48.54, epsilon = 0.710
# episode 290, reward = 45.77, epsilon = 0.706
# episode 300, reward = 44.53, epsilon = 0.700

# %%
# Plot losses
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)

# Original (noisy) loss curve
plt.plot(losses, label="Raw Loss", alpha=0.4)

# Smoothed loss curve (moving average)
window = 50
if len(losses) >= window:
    smoothed_losses = np.convolve(losses, np.ones(window)/window, mode='valid')
    plt.plot(range(window-1, window-1 + len(smoothed_losses)), smoothed_losses, label=f"Smoothed (window={window})", linewidth=2)

plt.xlabel("Update Step")
plt.ylabel("Loss")
plt.title("Loss During Training")
plt.legend()
plt.grid()

# Plot rewards
plt.subplot(1, 2, 2)
plt.plot(np.arange(1, len(rewards)+1) * 10, rewards, label="Eval Reward")
plt.xlabel("Episode")
plt.ylabel("Avg Reward (Eval)")
plt.title("Evaluation Reward Every 10 Episodes")
plt.grid()

plt.tight_layout()
plt.show()

# %%
print("Rewards after training = ", eval_agent(agent, env))
# Out:
# Rewards after training =  [37.50473934 43.75473934 56.25473934 43.75473934 41.358906  ]

# %%
test_rewards = eval_agent(agent, env, n_sim=20)
print("Average Test Reward:", np.mean(test_rewards))
# Out:
# Average Test Reward: 43.18649083882351

# %%
env = gym.make("highway-fast-v0", render_mode="rgb_array", config=config)
state, _ = env.reset()
done = False

for _ in range(100):
    with torch.no_grad():
        state_tensor = torch.FloatTensor(state).flatten().unsqueeze(0).to(device)
        action = torch.argmax(agent.q_net(state_tensor)).item()
    state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    img = env.render()
    plt.imshow(img)
    plt.axis("off")
    clear_output(wait=True)
    plt.show()
    time.sleep(0.1)
env.close()

# %% [markdown]
# ## Grid Search

# %%
# Hyperparameter grid
buffer_capacities = [10000, 20000, 50000]
update_frequencies = [100, 200, 500]

# %%
results = []

for buf_cap, update_freq in itertools.product(buffer_capacities, update_frequencies):
    print(f"\nTraining with buffer_capacity={buf_cap}, update_target_every={update_freq}")

    agent = DQN_Skeleton(
        action_space=env.action_space,
        observation_space=env.observation_space,
        gamma=0.99,
        batch_size=64,
        buffer_capacity=buf_cap,
        update_target_every=update_freq,
        epsilon_start=0.9,
        decrease_epsilon_factor=1000,
        epsilon_min=0.05,
        learning_rate=1e-4,
        hidden_size=128
    )

    N_episodes = 300
    losses, reward_history = train(env, agent, N_episodes=N_episodes)

    test_rewards = eval_agent(agent, env, n_sim=20)
    avg_test_reward = np.mean(test_rewards)
    print(f"Average Test Reward: {avg_test_reward:.2f}")

    results.append({
        "buffer_capacity": buf_cap,
        "update_target_every": update_freq,
        "losses": losses,
        "reward_history": reward_history,
        "final_avg_reward": reward_history[-1] if reward_history else 0,
        "max_reward": max(reward_history) if reward_history else 0,
        "min_reward": min(reward_history) if reward_history else 0,
        "avg_test_reward": avg_test_reward
    })
# Out:
# Training with buffer_capacity=10000, update_target_every=100
# episode 10, reward = 6.22, epsilon = 0.897
# episode 20, reward = 7.81, epsilon = 0.888
# episode 30, reward = 10.78, epsilon = 0.880
# episode 40, reward = 22.88, epsilon = 0.872
# episode 50, reward = 38.78, epsilon = 0.863
# episode 60, reward = 51.74, epsilon = 0.855
# episode 70, reward = 56.20, epsilon = 0.847
# episode 80, reward = 56.33, epsilon = 0.839
# episode 90, reward = 46.43, epsilon = 0.832
# episode 100, reward = 56.30, epsilon = 0.824
# episode 110, reward = 55.72, epsilon = 0.817
# episode 120, reward = 47.36, epsilon = 0.810
# episode 130, reward = 35.21, epsilon = 0.802
# episode 140, reward = 43.75, epsilon = 0.797
# episode 150, reward = 42.50, epsilon = 0.791
# episode 160, reward = 47.50, epsilon = 0.784
# episode 170, reward = 51.25, epsilon = 0.776
# episode 180, reward = 47.50, epsilon = 0.771
# episode 190, reward = 48.75, epsilon = 0.765
# episode 200, reward = 45.00, epsilon = 0.759
# episode 210, reward = 50.00, epsilon = 0.754
# episode 220, reward = 41.25, epsilon = 0.747
# episode 230, reward = 48.75, epsilon = 0.742
# episode 240, reward = 42.50, epsilon = 0.738
# episode 250, reward = 46.25, epsilon = 0.734
# episode 260, reward = 43.84, epsilon = 0.728
# episode 270, reward = 42.88, epsilon = 0.723
# episode 280, reward = 42.50, epsilon = 0.718
# episode 290, reward = 42.50, epsilon = 0.714
# episode 300, reward = 35.88, epsilon = 0.709
# Average Test Reward: 44.25
#
# Training with buffer_capacity=10000, update_target_every=200
# episode 10, reward = 22.26, epsilon = 0.897
# episode 20, reward = 6.83, epsilon = 0.888
# episode 30, reward = 11.40, epsilon = 0.880
# episode 40, reward = 5.78, epsilon = 0.872
# episode 50, reward = 8.57, epsilon = 0.863
# episode 60, reward = 9.57, epsilon = 0.855
# episode 70, reward = 5.10, epsilon = 0.847
# episode 80, reward = 15.27, epsilon = 0.839
# episode 90, reward = 7.00, epsilon = 0.832
# episode 100, reward = 8.46, epsilon = 0.824
# episode 110, reward = 22.00, epsilon = 0.816
# episode 120, reward = 9.89, epsilon = 0.808
# episode 130, reward = 7.20, epsilon = 0.801
# episode 140, reward = 45.71, epsilon = 0.793
# episode 150, reward = 46.71, epsilon = 0.786
# episode 160, reward = 51.02, epsilon = 0.779
# episode 170, reward = 43.75, epsilon = 0.771
# episode 180, reward = 44.63, epsilon = 0.766
# episode 190, reward = 46.25, epsilon = 0.760
# episode 200, reward = 47.65, epsilon = 0.756
# episode 210, reward = 43.84, epsilon = 0.749
# episode 220, reward = 45.07, epsilon = 0.744
# episode 230, reward = 46.17, epsilon = 0.738
# episode 240, reward = 40.00, epsilon = 0.732
# episode 250, reward = 47.78, epsilon = 0.726
# episode 260, reward = 45.05, epsilon = 0.720
# episode 270, reward = 43.84, epsilon = 0.714
# episode 280, reward = 53.40, epsilon = 0.709
# episode 290, reward = 38.90, epsilon = 0.702
# episode 300, reward = 53.53, epsilon = 0.697
# Average Test Reward: 49.78
#
# Training with buffer_capacity=10000, update_target_every=500
# episode 10, reward = 38.28, epsilon = 0.896
# episode 20, reward = 49.11, epsilon = 0.889
# episode 30, reward = 19.22, epsilon = 0.881
# episode 40, reward = 23.25, epsilon = 0.872
# episode 50, reward = 56.41, epsilon = 0.864
# episode 60, reward = 29.45, epsilon = 0.856
# episode 70, reward = 5.38, epsilon = 0.848
# episode 80, reward = 33.84, epsilon = 0.840
# episode 90, reward = 26.45, epsilon = 0.832
# episode 100, reward = 41.31, epsilon = 0.825
# episode 110, reward = 43.47, epsilon = 0.817
# episode 120, reward = 37.00, epsilon = 0.809
# episode 130, reward = 55.02, epsilon = 0.802
# episode 140, reward = 40.57, epsilon = 0.795
# episode 150, reward = 55.44, epsilon = 0.787
# episode 160, reward = 44.79, epsilon = 0.780
# episode 170, reward = 56.27, epsilon = 0.773
# episode 180, reward = 44.57, epsilon = 0.766
# episode 190, reward = 56.34, epsilon = 0.759
# episode 200, reward = 49.65, epsilon = 0.752
# episode 210, reward = 52.24, epsilon = 0.745
# episode 220, reward = 46.01, epsilon = 0.739
# episode 230, reward = 51.23, epsilon = 0.734
# episode 240, reward = 46.27, epsilon = 0.727
# episode 250, reward = 50.49, epsilon = 0.722
# episode 260, reward = 49.98, epsilon = 0.715
# episode 270, reward = 53.80, epsilon = 0.711
# episode 280, reward = 51.35, epsilon = 0.707
# episode 290, reward = 42.95, epsilon = 0.700
# episode 300, reward = 45.28, epsilon = 0.694
# Average Test Reward: 45.12
#
# Training with buffer_capacity=20000, update_target_every=100
# episode 10, reward = 10.33, epsilon = 0.897
# episode 20, reward = 9.82, epsilon = 0.888
# episode 30, reward = 16.29, epsilon = 0.881
# episode 40, reward = 19.26, epsilon = 0.872
# episode 50, reward = 14.61, epsilon = 0.864
# episode 60, reward = 25.34, epsilon = 0.856
# episode 70, reward = 25.49, epsilon = 0.849
# episode 80, reward = 35.34, epsilon = 0.841
# episode 90, reward = 44.04, epsilon = 0.834
# episode 100, reward = 33.10, epsilon = 0.828
# episode 110, reward = 50.12, epsilon = 0.821
# episode 120, reward = 46.25, epsilon = 0.815
# episode 130, reward = 48.57, epsilon = 0.807
# episode 140, reward = 47.65, epsilon = 0.800
# episode 150, reward = 48.76, epsilon = 0.793
# episode 160, reward = 51.33, epsilon = 0.786
# episode 170, reward = 49.82, epsilon = 0.779
# episode 180, reward = 44.94, epsilon = 0.772
# episode 190, reward = 47.50, epsilon = 0.766
# episode 200, reward = 47.50, epsilon = 0.760
# episode 210, reward = 46.25, epsilon = 0.753
# episode 220, reward = 55.00, epsilon = 0.747
# episode 230, reward = 51.17, epsilon = 0.740
# episode 240, reward = 42.00, epsilon = 0.734
# episode 250, reward = 47.50, epsilon = 0.728
# episode 260, reward = 44.32, epsilon = 0.723
# episode 270, reward = 45.00, epsilon = 0.717
# episode 280, reward = 52.50, epsilon = 0.714
# episode 290, reward = 45.00, epsilon = 0.709
# episode 300, reward = 49.05, epsilon = 0.703
# Average Test Reward: 47.09
#
# Training with buffer_capacity=20000, update_target_every=200
# episode 10, reward = 5.79, epsilon = 0.897
# episode 20, reward = 6.40, epsilon = 0.888
# episode 30, reward = 6.60, epsilon = 0.880
# episode 40, reward = 12.12, epsilon = 0.872
# episode 50, reward = 6.43, epsilon = 0.863
# episode 60, reward = 18.49, epsilon = 0.855
# episode 70, reward = 8.31, epsilon = 0.847
# episode 80, reward = 16.68, epsilon = 0.839
# episode 90, reward = 15.18, epsilon = 0.832
# episode 100, reward = 25.45, epsilon = 0.824
# episode 110, reward = 37.92, epsilon = 0.816
# episode 120, reward = 46.32, epsilon = 0.809
# episode 130, reward = 50.01, epsilon = 0.802
# episode 140, reward = 48.46, epsilon = 0.796
# episode 150, reward = 21.00, epsilon = 0.788
# episode 160, reward = 38.42, epsilon = 0.782
# episode 170, reward = 50.96, epsilon = 0.776
# episode 180, reward = 41.30, epsilon = 0.770
# episode 190, reward = 49.71, epsilon = 0.764
# episode 200, reward = 43.48, epsilon = 0.759
# episode 210, reward = 49.95, epsilon = 0.753
# episode 220, reward = 44.79, epsilon = 0.748
# episode 230, reward = 51.25, epsilon = 0.742
# episode 240, reward = 47.50, epsilon = 0.736
# episode 250, reward = 53.75, epsilon = 0.731
# episode 260, reward = 46.67, epsilon = 0.727
# episode 270, reward = 40.23, epsilon = 0.722
# episode 280, reward = 43.63, epsilon = 0.716
# episode 290, reward = 45.92, epsilon = 0.710
# episode 300, reward = 47.94, epsilon = 0.705
# Average Test Reward: 43.62
#
# Training with buffer_capacity=20000, update_target_every=500
# episode 10, reward = 12.83, epsilon = 0.897
# episode 20, reward = 11.83, epsilon = 0.888
# episode 30, reward = 13.26, epsilon = 0.880
# episode 40, reward = 30.83, epsilon = 0.872
# episode 50, reward = 28.67, epsilon = 0.864
# episode 60, reward = 7.40, epsilon = 0.856
# episode 70, reward = 15.06, epsilon = 0.848
# episode 80, reward = 11.97, epsilon = 0.840
# episode 90, reward = 37.02, epsilon = 0.832
# episode 100, reward = 30.12, epsilon = 0.826
# episode 110, reward = 15.31, epsilon = 0.818
# episode 120, reward = 49.37, epsilon = 0.812
# episode 130, reward = 37.54, epsilon = 0.805
# episode 140, reward = 43.32, epsilon = 0.797
# episode 150, reward = 50.97, epsilon = 0.790
# episode 160, reward = 41.18, epsilon = 0.784
# episode 170, reward = 40.60, epsilon = 0.779
# episode 180, reward = 46.04, epsilon = 0.771
# episode 190, reward = 50.07, epsilon = 0.764
# episode 200, reward = 53.45, epsilon = 0.758
# episode 210, reward = 44.12, epsilon = 0.752
# episode 220, reward = 44.92, epsilon = 0.746
# episode 230, reward = 42.57, epsilon = 0.740
# episode 240, reward = 47.57, epsilon = 0.735
# episode 250, reward = 34.90, epsilon = 0.729
# episode 260, reward = 43.05, epsilon = 0.723
# episode 270, reward = 52.22, epsilon = 0.717
# episode 280, reward = 42.36, epsilon = 0.712
# episode 290, reward = 42.88, epsilon = 0.707
# episode 300, reward = 41.48, epsilon = 0.702
# Average Test Reward: 44.88
#
# Training with buffer_capacity=50000, update_target_every=100
# episode 10, reward = 8.47, epsilon = 0.896
# episode 20, reward = 45.54, epsilon = 0.888
# episode 30, reward = 55.46, epsilon = 0.880
# episode 40, reward = 53.39, epsilon = 0.872
# episode 50, reward = 42.27, epsilon = 0.864
# episode 60, reward = 49.80, epsilon = 0.856
# episode 70, reward = 44.94, epsilon = 0.849
# episode 80, reward = 50.00, epsilon = 0.841
# episode 90, reward = 47.65, epsilon = 0.833
# episode 100, reward = 47.50, epsilon = 0.826
# episode 110, reward = 52.50, epsilon = 0.819
# episode 120, reward = 51.25, epsilon = 0.811
# episode 130, reward = 45.21, epsilon = 0.805
# episode 140, reward = 49.32, epsilon = 0.799
# episode 150, reward = 45.00, epsilon = 0.792
# episode 160, reward = 46.25, epsilon = 0.785
# episode 170, reward = 45.32, epsilon = 0.779
# episode 180, reward = 43.28, epsilon = 0.772
# episode 190, reward = 44.44, epsilon = 0.766
# episode 200, reward = 41.46, epsilon = 0.760
# episode 210, reward = 51.82, epsilon = 0.754
# episode 220, reward = 41.40, epsilon = 0.747
# episode 230, reward = 48.75, epsilon = 0.741
# episode 240, reward = 47.54, epsilon = 0.736
# episode 250, reward = 52.48, epsilon = 0.732
# episode 260, reward = 48.03, epsilon = 0.727
# episode 270, reward = 44.73, epsilon = 0.723
# episode 280, reward = 50.94, epsilon = 0.719
# episode 290, reward = 51.25, epsilon = 0.713
# episode 300, reward = 51.25, epsilon = 0.708
# Average Test Reward: 45.21
#
# Training with buffer_capacity=50000, update_target_every=200
# episode 10, reward = 19.70, epsilon = 0.895
# episode 20, reward = 19.26, epsilon = 0.887
# episode 30, reward = 32.24, epsilon = 0.878
# episode 40, reward = 45.09, epsilon = 0.870
# episode 50, reward = 39.34, epsilon = 0.862
# episode 60, reward = 33.68, epsilon = 0.854
# episode 70, reward = 33.77, epsilon = 0.846
# episode 80, reward = 43.19, epsilon = 0.839
# episode 90, reward = 52.13, epsilon = 0.831
# episode 100, reward = 31.33, epsilon = 0.823
# episode 110, reward = 30.70, epsilon = 0.815
# episode 120, reward = 44.54, epsilon = 0.808
# episode 130, reward = 44.10, epsilon = 0.801
# episode 140, reward = 51.26, epsilon = 0.793
# episode 150, reward = 53.80, epsilon = 0.786
# episode 160, reward = 52.03, epsilon = 0.780
# episode 170, reward = 47.34, epsilon = 0.773
# episode 180, reward = 45.00, epsilon = 0.766
# episode 190, reward = 45.22, epsilon = 0.761
# episode 200, reward = 51.19, epsilon = 0.754
# episode 210, reward = 44.92, epsilon = 0.749
# episode 220, reward = 47.50, epsilon = 0.742
# episode 230, reward = 46.25, epsilon = 0.735
# episode 240, reward = 45.03, epsilon = 0.729
# episode 250, reward = 51.25, epsilon = 0.723
# episode 260, reward = 45.48, epsilon = 0.718
# episode 270, reward = 50.00, epsilon = 0.713
# episode 280, reward = 45.63, epsilon = 0.708
# episode 290, reward = 39.92, epsilon = 0.703
# episode 300, reward = 52.50, epsilon = 0.698
# Average Test Reward: 43.83
#
# Training with buffer_capacity=50000, update_target_every=500
# episode 10, reward = 19.85, epsilon = 0.893
# episode 20, reward = 12.57, epsilon = 0.885
# episode 30, reward = 12.14, epsilon = 0.877
# episode 40, reward = 15.82, epsilon = 0.868
# episode 50, reward = 29.47, epsilon = 0.861
# episode 60, reward = 15.43, epsilon = 0.853
# episode 70, reward = 24.31, epsilon = 0.846
# episode 80, reward = 25.14, epsilon = 0.838
# episode 90, reward = 54.54, epsilon = 0.830
# episode 100, reward = 26.98, epsilon = 0.822
# episode 110, reward = 29.20, epsilon = 0.815
# episode 120, reward = 45.88, epsilon = 0.808
# episode 130, reward = 21.99, epsilon = 0.800
# episode 140, reward = 46.74, epsilon = 0.793
# episode 150, reward = 45.11, epsilon = 0.785
# episode 160, reward = 45.76, epsilon = 0.778
# episode 170, reward = 24.64, epsilon = 0.771
# episode 180, reward = 55.41, epsilon = 0.764
# episode 190, reward = 52.20, epsilon = 0.757
# episode 200, reward = 43.75, epsilon = 0.750
# episode 210, reward = 51.71, epsilon = 0.744
# episode 220, reward = 52.05, epsilon = 0.737
# episode 230, reward = 52.58, epsilon = 0.730
# episode 240, reward = 47.14, epsilon = 0.725
# episode 250, reward = 47.57, epsilon = 0.721
# episode 260, reward = 41.21, epsilon = 0.715
# episode 270, reward = 35.19, epsilon = 0.708
# episode 280, reward = 42.50, epsilon = 0.703
# episode 290, reward = 45.54, epsilon = 0.698
# episode 300, reward = 45.90, epsilon = 0.693
# Average Test Reward: 42.36

# %%
summary_df = pd.DataFrame([
    {
        "buffer_capacity": r["buffer_capacity"],
        "update_target_every": r["update_target_every"],
        "final_avg_reward": r["final_avg_reward"],
        "max_reward": r["max_reward"],
        "min_reward": r["min_reward"],
        "avg_test_reward": r["avg_test_reward"]
    }
    for r in results
])

summary_df = summary_df.sort_values(by="avg_test_reward", ascending=False)

# %%
summary_df
# Out:
#    buffer_capacity  update_target_every  final_avg_reward  max_reward  \
# 1            10000                  200         53.525572   53.525572
# 3            20000                  100         49.046406   55.004739
# 6            50000                  100         51.254641   55.456731
# 2            10000                  500         45.275558   56.407783
# 5            20000                  500         41.483906   53.452656
# 0            10000                  100         35.879739   56.325393
# 7            50000                  200         52.504739   53.800572
# 4            20000                  200         47.942237   53.754739
# 8            50000                  500         45.904723   55.412070
#
#    min_reward  avg_test_reward
# 1    5.096095        49.780777
# 3    9.819146        47.088072
# 6    8.470786        45.209390
# 2    5.382910        45.119318
# 5    7.395813        44.875573
# 0    6.223129        44.254739
# 7   19.258217        43.833623
# 4    5.785579        43.624530
# 8   12.136452        42.360448

# %%
with open("gridsearch_dqn_results.pkl", "wb") as f:
    pickle.dump(results, f)

# %%
with open("gridsearch_dqn_results.pkl", "rb") as f:
    results = pickle.load(f)

# %%
unique_buffers = sorted(set(r["buffer_capacity"] for r in results))

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
for idx, buf in enumerate(unique_buffers):
    ax = axes[idx]
    for result in results:
        if result["buffer_capacity"] == buf:
            label = f"update={result['update_target_every']}"
            ax.plot(result["reward_history"], label=label)
    ax.set_title(f"Buffer = {buf}")
    ax.set_xlabel("Eval Step (x10 episodes)")
    if idx == 0:
        ax.set_ylabel("Avg Reward")
    ax.grid(True)
    ax.legend()

fig.suptitle("Evaluation Rewards — Grouped by Buffer Capacity", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
unique_updates = sorted(set(r["update_target_every"] for r in results))

fig, axes = plt.subplots(1, 3, figsize=(18, 5), sharey=True)
for idx, upd in enumerate(unique_updates):
    ax = axes[idx]
    for result in results:
        if result["update_target_every"] == upd:
            label = f"buffer={result['buffer_capacity']}"
            ax.plot(result["reward_history"], label=label)
    ax.set_title(f"Update Freq = {upd}")
    ax.set_xlabel("Eval Step (x10 episodes)")
    if idx == 0:
        ax.set_ylabel("Avg Reward")
    ax.grid(True)
    ax.legend()

fig.suptitle("Evaluation Rewards — Grouped by Update Frequency", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
window = 50
plt.figure(figsize=(8, 6))

for result in results:
    label = f"buf_cap={result['buffer_capacity']}, update={result['update_target_every']}"
    losses = result["losses"]

    if len(losses) >= window:
        smoothed = np.convolve(losses, np.ones(window)/window, mode='valid')
        x_vals = range(window - 1, window - 1 + len(smoothed))
        plt.plot(x_vals, smoothed, label=label)

plt.xlabel("Update Step")
plt.ylabel("Smoothed Loss")
plt.title(f"Training Loss (Smoothed with Window={window})")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
